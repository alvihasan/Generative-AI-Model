# %% [markdown]
# ## Imports

# %%
# %%capture
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip install pyvirtualdisplay
# !pip install pyglet==1.5.1

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
# !pip install -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt
# Out:
# Collecting git+https://github.com/ntasfi/PyGame-Learning-Environment.git (from -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt (line 1))
#   Cloning https://github.com/ntasfi/PyGame-Learning-Environment.git to /tmp/pip-req-build-_75i3zap
#   Running command git clone --filter=blob:none --quiet https://github.com/ntasfi/PyGame-Learning-Environment.git /tmp/pip-req-build-_75i3zap
#   Resolved https://github.com/ntasfi/PyGame-Learning-Environment.git to commit 3dbe79dc0c35559bb441b9359948aabf9bb3d331
#   Preparing metadata (setup.py) ... done
# Collecting git+https://github.com/simoninithomas/gym-games (from -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt (line 2))
#   Cloning https://github.com/simoninithomas/gym-games to /tmp/pip-req-build-mx4rzg9v
#   Running command git clone --filter=blob:none --quiet https://github.com/simoninithomas/gym-games /tmp/pip-req-build-mx4rzg9v
#   Resolved https://github.com/simoninithomas/gym-games to commit f31695e4ba028400628dc054ee8a436f28193f0b
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt (line 3)) (0.24.7)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt (line 4)) (0.5.1)
# Collecting pyyaml==6.0 (from -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt (line 5))
#   Downloading PyYAML-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ple==0.0.1->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt (line 1)) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from ple==0.0.1->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt (line 1)) (10.4.0)
# Requirement already satisfied: gym>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from gym-games==1.0.4->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt (line 2)) (0.25.2)
# Requirement already satisfied: setuptools>=65.5.1 in /usr/local/lib/python3.10/dist-packages (from gym-games==1.0.4->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt (line 2)) (75.1.0)
# Requirement already satisfied: pygame>=1.9.6 in /usr/local/lib/python3.10/dist-packages (from gym-games==1.0.4->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt (line 2)) (2.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt (line 3)) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt (line 3)) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt (line 3)) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt (line 3)) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt (line 3)) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt (line 3)) (4.12.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym>=0.13.0->gym-games==1.0.4->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt (line 2)) (3.1.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym>=0.13.0->gym-games==1.0.4->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt (line 2)) (0.0.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt (line 3)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt (line 3)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt (line 3)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit4/requirements-unit4.txt (line 3)) (2024.8.30)
# Downloading PyYAML-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (682 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.2/682.2 kB 20.8 MB/s eta 0:00:00
# Building wheels for collected packages: ple, gym-games
#   Building wheel for ple (setup.py) ... done
#   Created wheel for ple: filename=ple-0.0.1-py3-none-any.whl size=50772 sha256=884bf1a0c9bcb5cc01e6477b232be3d32ffebd6e6afe5b07635cba26efe422ef
#   Stored in directory: /tmp/pip-ephem-wheel-cache-le0z0h78/wheels/f8/31/ca/a64a7ce73540465412d82813780d062db53b90e3f42a4ecb7f
#   Building wheel for gym-games (setup.py) ... done
#   Created wheel for gym-games: filename=gym_games-1.0.4-py3-none-any.whl size=17306 sha256=8499bbdd8cdfa2a82bba4935ba958143dd5048efc8b9083e8991794f10dda360
#   Stored in directory: /tmp/pip-ephem-wheel-cache-le0z0h78/wheels/ca/bf/6b/7d631626202ebb033c908a688d1862ff4d948c34cf621d7dc9
# Successfully built ple gym-games
# Installing collected packages: pyyaml, ple, gym-games
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.2
#     Uninstalling PyYAML-6.0.2:
#       Successfully uninstalled PyYAML-6.0.2
# Successfully installed gym-games-1.0.4 ple-0.0.1 pyyaml-6.0

# %%
from ple.games.pong import Pong
from ple import PLE
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# couldn't import doomish
# Couldn't import doom

# %%
import numpy as np

from collections import deque

import matplotlib.pyplot as plt
# %matplotlib inline

# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

# Gym
import gym
import gym_pygame

# Hugging Face Hub
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
import imageio

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def images_to_video(images, out_directory, fps=30):
    imageio.mimsave(out_directory, [np.array(img) for i, img in enumerate(images)], fps=fps)

# %%
# !rm -rf /content/training

# %%
import os
os.makedirs("/content/training")

# %% [markdown]
# ## Main Part

# %%
hyperparameters = {
    "h_size": 512,
    "n_training_episodes": 2000,
    "n_evaluation_episodes": 10,
    "max_t": 500,
    "gamma": 1e-5,
    "lr": 1e-6,
}

# %%
env = Pong()
game = PLE(env, display_screen=False)

# %%
game.init()
game.reset_game()
print(game.getActionSet())
img = game.getScreenGrayscale()
print(img.shape)

# %%
game.act(119)

# %%
img = game.getScreenGrayscale()
img

# %%
img.shape

# %%
class PolicyNetwork(nn.Module):
    def __init__(self, H, learning_rate, input_shape=(64, 48), num_actions=3):
        super(PolicyNetwork, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.fc1 = nn.Linear(self.feature_size(input_shape), H)
        self.fc2 = nn.Linear(H, num_actions)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)  # Use Adam optimizer


    def feature_size(self, input_shape):
        x = torch.zeros(1, *input_shape)
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        return x.view(1, -1).size(1)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = x.view(x.size(0), -1) # flatten
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.softmax(x, dim=1)

    def act(self, x):
        state = torch.from_numpy(np.array(x)).float().to(device)
        # Normalize
        state = (state - state.mean()) / (state.std() + 1e-8)

        state = state.unsqueeze(0)  # Add Channel dimension
        state = state.unsqueeze(0)  # Add batch dimension

        # print(state.size())

        probs = self.forward(state)
        m = Categorical(probs)
        # Sampling an action based on probability
        action = m.sample()
        return action.item(), m.log_prob(action)

# %%
action_map = {
    0: 119,
    1: 115,
    2: None
}

# %%
# Initialize the model
model = PolicyNetwork(hyperparameters["h_size"], hyperparameters["lr"]).to(device)

# %%
def reinforce(policy, optimizer, n_training_episodes, max_t, gamma, print_every):
    # Help us to calculate the score during the training
    scores_deque = deque(maxlen=100)
    scores = []

    # Line 3 of pseudocode
    for i_episode in range(1, n_training_episodes+1):
        saved_log_probs = []
        rewards = []

        images = []

        game.reset_game()
        state_ = game.getScreenGrayscale()

        # Line 4 of pseudocode
        for t in range(max_t):
            state = game.getScreenGrayscale()
            action, log_prob = policy.act(state)
            # state, state_ = state - state_, state
            # action, log_prob = policy.act(state)
            saved_log_probs.append(log_prob)

            reward = game.act(action_map[action])
            rewards.append(reward)

            images.append(state)

            if game.game_over():
                break


        if i_episode % print_every == 0:
            images_to_video(images, f"/content/training/pong-training-{i_episode}.mp4")

        scores_deque.append(sum(rewards))
        scores.append(sum(rewards))

        # Line 6 of pseudocode: calculate the return
        returns = deque(maxlen=max_t)
        n_steps = len(rewards)
        # Compute the discounted returns at each timestep,
        # as the sum of the gamma-discounted return at time t (G_t) + the reward at time t
        #
        # In O(N) time, where N is the number of time steps
        # (this definition of the discounted return G_t follows the definition of this quantity
        # shown at page 44 of Sutton&Barto 2017 2nd draft)
        # G_t = r_(t+1) + r_(t+2) + ...

        # Given this formulation, the returns at each timestep t can be computed
        # by re-using the computed future returns G_(t+1) to compute the current return G_t
        # G_t = r_(t+1) + gamma*G_(t+1)
        # G_(t-1) = r_t + gamma* G_t
        # (this follows a dynamic programming approach, with which we memorize solutions in order
        # to avoid computing them multiple times)

        # This is correct since the above is equivalent to (see also page 46 of Sutton&Barto 2017 2nd draft)
        # G_(t-1) = r_t + gamma*r_(t+1) + gamma*gamma*r_(t+2) + ...


        ## Given the above, we calculate the returns at timestep t as:
        #               gamma[t] * return[t] + reward[t]
        #
        ## We compute this starting from the last timestep to the first, in order
        ## to employ the formula presented above and avoid redundant computations that would be needed
        ## if we were to do it from first to last.

        ## Hence, the queue "returns" will hold the returns in chronological order, from t=0 to t=n_steps
        ## thanks to the appendleft() function which allows to append to the position 0 in constant time O(1)
        ## a normal python list would instead require O(N) to do this.
        for t in range(n_steps)[::-1]:
            disc_return_t = (returns[0] if len(returns)>0 else 0)
            returns.appendleft( gamma*disc_return_t + rewards[t]   )

        ## standardization of the returns is employed to make training more stable
        eps = np.finfo(np.float32).eps.item()
        ## eps is the smallest representable float, which is
        # added to the standard deviation of the returns to avoid numerical instabilities
        returns = torch.tensor(returns)
        returns = (returns - returns.mean()) / (returns.std() + eps)

        # Line 7:
        policy_loss = []
        for log_prob, disc_return in zip(saved_log_probs, returns):
            policy_loss.append(-log_prob * disc_return)
        policy_loss = torch.cat(policy_loss).sum()

        # Line 8: PyTorch prefers gradient descent
        optimizer.zero_grad()
        policy_loss.backward()
        optimizer.step()

        if i_episode % print_every == 0:
            print('Episode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))

    return scores

# %%
scores = reinforce(
    model,
    model.optimizer,
    hyperparameters["n_training_episodes"],
    hyperparameters["max_t"],
    hyperparameters["gamma"],
    5
)
# Out:
# Episode 5	Average Score: -12.00
# Episode 10	Average Score: -11.80
# Episode 15	Average Score: -11.73
# Episode 20	Average Score: -11.55
# Episode 25	Average Score: -11.48
# Episode 30	Average Score: -11.67
# Episode 35	Average Score: -11.57
# Episode 40	Average Score: -11.93
# Episode 45	Average Score: -11.82
# Episode 50	Average Score: -12.06
# Episode 55	Average Score: -11.84
# Episode 60	Average Score: -11.95
# Episode 65	Average Score: -12.26
# Episode 70	Average Score: -11.91
# Episode 75	Average Score: -11.71
# Episode 80	Average Score: -11.74
# Episode 85	Average Score: -11.80
# Episode 90	Average Score: -11.72
# Episode 95	Average Score: -11.88
# Episode 100	Average Score: -11.95
# Episode 105	Average Score: -12.15
# Episode 110	Average Score: -12.15
# Episode 115	Average Score: -12.20
# Episode 120	Average Score: -12.30
# Episode 125	Average Score: -12.31
# Episode 130	Average Score: -12.28
# Episode 135	Average Score: -12.21
# Episode 140	Average Score: -12.29
# Episode 145	Average Score: -12.46
# Episode 150	Average Score: -12.49
# Episode 155	Average Score: -12.63
# Episode 160	Average Score: -12.56
# Episode 165	Average Score: -12.35
# Episode 170	Average Score: -12.70
# Episode 175	Average Score: -12.91
# Episode 180	Average Score: -13.10
# Episode 185	Average Score: -13.20
# Episode 190	Average Score: -13.41
# Episode 195	Average Score: -13.40
# Episode 200	Average Score: -13.34
# Episode 205	Average Score: -13.22
# Episode 210	Average Score: -13.29
# Episode 215	Average Score: -13.39
# Episode 220	Average Score: -13.47
# Episode 225	Average Score: -13.43
# Episode 230	Average Score: -13.55
# Episode 235	Average Score: -13.81
# Episode 240	Average Score: -13.57
# Episode 245	Average Score: -13.53
# Episode 250	Average Score: -13.27
# Episode 255	Average Score: -13.24
# Episode 260	Average Score: -13.17
# Episode 265	Average Score: -13.38
# Episode 270	Average Score: -13.17
# Episode 275	Average Score: -13.19
# Episode 280	Average Score: -13.02
# Episode 285	Average Score: -12.94
# Episode 290	Average Score: -12.87
# Episode 295	Average Score: -12.81
# Episode 300	Average Score: -12.93
# Episode 305	Average Score: -12.98
# Episode 310	Average Score: -12.89
# Episode 315	Average Score: -12.81
# Episode 320	Average Score: -12.73
# Episode 325	Average Score: -12.85
# Episode 330	Average Score: -12.87
# Episode 335	Average Score: -12.76
# Episode 340	Average Score: -12.86
# Episode 345	Average Score: -12.88
# Episode 350	Average Score: -13.20
# Episode 355	Average Score: -13.41
# Episode 360	Average Score: -13.51
# Episode 365	Average Score: -13.34
# Episode 370	Average Score: -13.50
# Episode 375	Average Score: -13.50
# Episode 380	Average Score: -13.61
# Episode 385	Average Score: -13.60
# Episode 390	Average Score: -13.59
# Episode 395	Average Score: -13.59
# Episode 400	Average Score: -13.52
# Episode 405	Average Score: -13.44
# Episode 410	Average Score: -13.61
# Episode 415	Average Score: -13.69
# Episode 420	Average Score: -13.68
# Episode 425	Average Score: -13.65
# Episode 430	Average Score: -13.63
# Episode 435	Average Score: -13.60
# Episode 440	Average Score: -13.51
# Episode 445	Average Score: -13.61
# Episode 450	Average Score: -13.42
# Episode 455	Average Score: -13.28
# Episode 460	Average Score: -13.18
# Episode 465	Average Score: -13.00
# Episode 470	Average Score: -12.84
# Episode 475	Average Score: -12.66
# Episode 480	Average Score: -12.57
# Episode 485	Average Score: -12.49
# Episode 490	Average Score: -12.36
# Episode 495	Average Score: -12.43
# Episode 500	Average Score: -12.25
# Episode 505	Average Score: -12.33
# Episode 510	Average Score: -12.34
# Episode 515	Average Score: -12.21
# Episode 520	Average Score: -12.16
# Episode 525	Average Score: -12.20
# Episode 530	Average Score: -12.20
# Episode 535	Average Score: -12.06
# Episode 540	Average Score: -12.12
# Episode 545	Average Score: -12.05
# Episode 550	Average Score: -12.12
# Episode 555	Average Score: -12.10
# Episode 560	Average Score: -12.11
# Episode 565	Average Score: -12.39
# Episode 570	Average Score: -12.53
# Episode 575	Average Score: -12.65
# Episode 580	Average Score: -12.73
# Episode 585	Average Score: -12.76
# Episode 590	Average Score: -12.94
# Episode 595	Average Score: -12.70
# Episode 600	Average Score: -12.90
# Episode 605	Average Score: -12.89
# Episode 610	Average Score: -12.74
# Episode 615	Average Score: -12.68
# Episode 620	Average Score: -12.59
# Episode 625	Average Score: -12.64
# Episode 630	Average Score: -12.72
# Episode 635	Average Score: -12.93
# Episode 640	Average Score: -12.96
# Episode 645	Average Score: -12.76
# Episode 650	Average Score: -12.66
# Episode 655	Average Score: -12.69
# Episode 660	Average Score: -12.69
# Episode 665	Average Score: -12.48
# Episode 670	Average Score: -12.42
# Episode 675	Average Score: -12.37
# Episode 680	Average Score: -12.38
# Episode 685	Average Score: -12.50
# Episode 690	Average Score: -12.42
# Episode 695	Average Score: -12.33
# Episode 700	Average Score: -12.36
# Episode 705	Average Score: -12.15
# Episode 710	Average Score: -12.27
# Episode 715	Average Score: -12.25
# Episode 720	Average Score: -12.34
# Episode 725	Average Score: -12.12
# Episode 730	Average Score: -11.97
# Episode 735	Average Score: -11.85
# Episode 740	Average Score: -11.69
# Episode 745	Average Score: -11.81
# Episode 750	Average Score: -11.89
# Episode 755	Average Score: -11.83
# Episode 760	Average Score: -11.94
# Episode 765	Average Score: -12.22
# Episode 770	Average Score: -12.20
# Episode 775	Average Score: -12.44
# Episode 780	Average Score: -12.35
# Episode 785	Average Score: -12.37
# Episode 790	Average Score: -12.40
# Episode 795	Average Score: -12.72
# Episode 800	Average Score: -12.75
# Episode 805	Average Score: -12.98
# Episode 810	Average Score: -12.80
# Episode 815	Average Score: -13.08
# Episode 820	Average Score: -13.23
# Episode 825	Average Score: -13.40
# Episode 830	Average Score: -13.37
# Episode 835	Average Score: -13.53
# Episode 840	Average Score: -13.65
# Episode 845	Average Score: -13.42
# Episode 850	Average Score: -13.21
# Episode 855	Average Score: -13.26
# Episode 860	Average Score: -13.35
# Episode 865	Average Score: -13.09
# Episode 870	Average Score: -13.25
# Episode 875	Average Score: -13.19
# Episode 880	Average Score: -13.22
# Episode 885	Average Score: -13.15
# Episode 890	Average Score: -13.21
# Episode 895	Average Score: -13.01
# Episode 900	Average Score: -12.94
# Episode 905	Average Score: -12.94
# Episode 910	Average Score: -13.02
# Episode 915	Average Score: -13.02
# Episode 920	Average Score: -12.81
# Episode 925	Average Score: -12.95
# Episode 930	Average Score: -13.06
# Episode 935	Average Score: -13.08
# Episode 940	Average Score: -13.13
# Episode 945	Average Score: -13.44
# Episode 950	Average Score: -13.63
# Episode 955	Average Score: -13.52
# Episode 960	Average Score: -13.47
# Episode 965	Average Score: -13.66
# Episode 970	Average Score: -13.73
# Episode 975	Average Score: -13.37
# Episode 980	Average Score: -13.37
# Episode 985	Average Score: -13.37
# Episode 990	Average Score: -13.23
# Episode 995	Average Score: -13.43
# Episode 1000	Average Score: -13.34
# Episode 1005	Average Score: -13.25
# Episode 1010	Average Score: -13.27
# Episode 1015	Average Score: -13.05
# Episode 1020	Average Score: -13.26
# Episode 1025	Average Score: -13.13
# Episode 1030	Average Score: -13.10
# Episode 1035	Average Score: -13.02
# Episode 1040	Average Score: -12.99
# Episode 1045	Average Score: -12.76
# Episode 1050	Average Score: -12.79
# Episode 1055	Average Score: -12.92
# Episode 1060	Average Score: -12.98
# Episode 1065	Average Score: -12.91
# Episode 1070	Average Score: -12.75
# Episode 1075	Average Score: -12.90
# Episode 1080	Average Score: -12.79
# Episode 1085	Average Score: -12.84
# Episode 1090	Average Score: -12.81
# Episode 1095	Average Score: -12.70
# Episode 1100	Average Score: -12.83
# Episode 1105	Average Score: -12.73
# Episode 1110	Average Score: -12.63
# Episode 1115	Average Score: -12.85
# Episode 1120	Average Score: -12.77
# Episode 1125	Average Score: -12.64
# Episode 1130	Average Score: -12.47
# Episode 1135	Average Score: -12.37
# Episode 1140	Average Score: -12.39
# Episode 1145	Average Score: -12.57
# Episode 1150	Average Score: -12.47
# Episode 1155	Average Score: -12.51
# Episode 1160	Average Score: -12.36
# Episode 1165	Average Score: -12.33
# Episode 1170	Average Score: -12.35
# Episode 1175	Average Score: -12.50
# Episode 1180	Average Score: -12.47
# Episode 1185	Average Score: -12.20
# Episode 1190	Average Score: -12.18
# Episode 1195	Average Score: -12.20
# Episode 1200	Average Score: -12.20
# Episode 1205	Average Score: -12.17
# Episode 1210	Average Score: -12.28
# Episode 1215	Average Score: -12.07
# Episode 1220	Average Score: -11.81
# Episode 1225	Average Score: -11.78
# Episode 1230	Average Score: -11.97
# Episode 1235	Average Score: -11.92
# Episode 1240	Average Score: -11.99
# Episode 1245	Average Score: -11.72
# Episode 1250	Average Score: -11.95
# Episode 1255	Average Score: -11.86
# Episode 1260	Average Score: -11.83
# Episode 1265	Average Score: -11.75
# Episode 1270	Average Score: -11.64
# Episode 1275	Average Score: -11.62
# Episode 1280	Average Score: -11.74
# Episode 1285	Average Score: -12.09
# Episode 1290	Average Score: -12.20
# Episode 1295	Average Score: -12.22
# Episode 1300	Average Score: -12.14
# Episode 1305	Average Score: -12.26
# Episode 1310	Average Score: -12.42
# Episode 1315	Average Score: -12.53
# Episode 1320	Average Score: -12.71
# Episode 1325	Average Score: -12.80
# Episode 1330	Average Score: -12.68
# Episode 1335	Average Score: -12.80
# Episode 1340	Average Score: -12.75
# Episode 1345	Average Score: -12.98
# Episode 1350	Average Score: -12.86
# Episode 1355	Average Score: -12.93
# Episode 1360	Average Score: -13.10
# Episode 1365	Average Score: -13.17
# Episode 1370	Average Score: -13.35
# Episode 1375	Average Score: -13.49
# Episode 1380	Average Score: -13.43
# Episode 1385	Average Score: -13.24
# Episode 1390	Average Score: -13.21
# Episode 1395	Average Score: -13.09
# Episode 1400	Average Score: -13.07
# Episode 1405	Average Score: -13.13
# Episode 1410	Average Score: -12.95
# Episode 1415	Average Score: -12.79
# Episode 1420	Average Score: -12.85
# Episode 1425	Average Score: -13.05
# Episode 1430	Average Score: -12.98
# Episode 1435	Average Score: -12.98
# Episode 1440	Average Score: -13.04
# Episode 1445	Average Score: -12.98
# Episode 1450	Average Score: -12.77
# Episode 1455	Average Score: -12.81
# Episode 1460	Average Score: -12.74
# Episode 1465	Average Score: -12.85
# Episode 1470	Average Score: -12.78
# Episode 1475	Average Score: -12.70
# Episode 1480	Average Score: -12.78
# Episode 1485	Average Score: -12.87
# Episode 1490	Average Score: -13.00
# Episode 1495	Average Score: -13.17
# Episode 1500	Average Score: -13.04
# Episode 1505	Average Score: -13.08
# Episode 1510	Average Score: -13.05
# Episode 1515	Average Score: -13.03
# Episode 1520	Average Score: -13.13
# Episode 1525	Average Score: -13.01
# Episode 1530	Average Score: -13.12
# Episode 1535	Average Score: -13.02
# Episode 1540	Average Score: -13.01
# Episode 1545	Average Score: -13.00
# Episode 1550	Average Score: -12.98
# Episode 1555	Average Score: -12.81
# Episode 1560	Average Score: -12.88
# Episode 1565	Average Score: -12.73
# Episode 1570	Average Score: -12.58
# Episode 1575	Average Score: -12.53
# Episode 1580	Average Score: -12.40
# Episode 1585	Average Score: -12.50
# Episode 1590	Average Score: -12.50
# Episode 1595	Average Score: -12.38
# Episode 1600	Average Score: -12.57
# Episode 1605	Average Score: -12.63
# Episode 1610	Average Score: -12.68
# Episode 1615	Average Score: -12.90
# Episode 1620	Average Score: -12.82
# Episode 1625	Average Score: -12.78
# Episode 1630	Average Score: -12.73
# Episode 1635	Average Score: -12.84
# Episode 1640	Average Score: -12.84
# Episode 1645	Average Score: -12.80
# Episode 1650	Average Score: -13.15
# Episode 1655	Average Score: -13.19
# Episode 1660	Average Score: -12.93
# Episode 1665	Average Score: -12.98
# Episode 1670	Average Score: -13.17
# Episode 1675	Average Score: -13.23
# Episode 1680	Average Score: -13.41
# Episode 1685	Average Score: -13.05
# Episode 1690	Average Score: -13.06
# Episode 1695	Average Score: -13.10
# Episode 1700	Average Score: -13.14
# Episode 1705	Average Score: -12.82
# Episode 1710	Average Score: -12.78
# Episode 1715	Average Score: -12.66
# Episode 1720	Average Score: -12.70
# Episode 1725	Average Score: -12.86
# Episode 1730	Average Score: -12.77
# Episode 1735	Average Score: -12.86
# Episode 1740	Average Score: -12.65
# Episode 1745	Average Score: -12.70
# Episode 1750	Average Score: -12.47
# Episode 1755	Average Score: -12.66
# Episode 1760	Average Score: -12.80
# Episode 1765	Average Score: -12.79
# Episode 1770	Average Score: -12.82
# Episode 1775	Average Score: -12.63
# Episode 1780	Average Score: -12.60
# Episode 1785	Average Score: -12.66
# Episode 1790	Average Score: -12.50
# Episode 1795	Average Score: -12.40
# Episode 1800	Average Score: -12.27
# Episode 1805	Average Score: -12.47
# Episode 1810	Average Score: -12.34
# Episode 1815	Average Score: -12.30
# Episode 1820	Average Score: -12.24
# Episode 1825	Average Score: -12.18
# Episode 1830	Average Score: -12.32
# Episode 1835	Average Score: -12.40
# Episode 1840	Average Score: -12.30
# Episode 1845	Average Score: -12.37
# Episode 1850	Average Score: -12.60
# Episode 1855	Average Score: -12.40
# Episode 1860	Average Score: -12.45
# Episode 1865	Average Score: -12.36
# Episode 1870	Average Score: -12.25
# Episode 1875	Average Score: -12.38
# Episode 1880	Average Score: -12.41
# Episode 1885	Average Score: -12.51
# Episode 1890	Average Score: -12.49
# Episode 1895	Average Score: -12.62
# Episode 1900	Average Score: -12.71
# Episode 1905	Average Score: -12.70
# Episode 1910	Average Score: -12.96
# Episode 1915	Average Score: -13.06
# Episode 1920	Average Score: -13.06
# Episode 1925	Average Score: -13.12
# Episode 1930	Average Score: -13.14
# Episode 1935	Average Score: -13.08
# Episode 1940	Average Score: -13.33
# Episode 1945	Average Score: -13.42
# Episode 1950	Average Score: -13.35
# Episode 1955	Average Score: -13.41
# Episode 1960	Average Score: -13.41
# Episode 1965	Average Score: -13.61
# Episode 1970	Average Score: -13.57
# Episode 1975	Average Score: -13.70
# Episode 1980	Average Score: -13.56
# Episode 1985	Average Score: -13.76
# Episode 1990	Average Score: -13.79
# Episode 1995	Average Score: -13.73
# Episode 2000	Average Score: -13.67

# %%
from IPython.display import Video

Video("/content/training/pong-training-200.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
